# %% [markdown]
# ![](netflixlogo.jpg)

# %% [markdown]
#  <img src="netflixlogo.png" style="width:280px;height:280px">

# %%
# Importing the dataset

import pandas as pd

data = pd.read_csv(r"C:\Users\bikas\Downloads\python\ProjectNetflix\NetflixDataset.csv")

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# #### Getting some basic information about the dataset:

# %% [markdown]
# #### 1.head():

# %%
data.head()                  # To show top 5 records of the dataset
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# #### 2.tail():

# %%
data.tail()                  # To show bottom 5 records of the dataset
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# #### 3.shape:

# %%
data.shape                   # To show the no of rows and columns
# Out:
# (8807, 12)

# %% [markdown]
# #### 4.size:

# %%
data.size                    # To show no. of total values(elements) in the dataset
# Out:
# 105684

# %% [markdown]
# #### 5.columns:

# %%
data.columns                 # To show each column
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# #### 6.dtypes:

# %%
data.dtypes                                  # To show the data-type of each column
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# #### 7.info():

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# #### Task 1: Is there any duplicate records in this dataset? If yes, then remove the duplicate records.
#
# #### duplicate()

# %%
data[data.duplicated()]                      # To check row wise and detect the dupicate rows
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# #### Task 2: Is there any null values present in any columns? Show with heat-map
#
# #### isnull()

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
data_is_null = data.isnull()                 # To show where null value is present

# %%
data_is_null.sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# #### seaborn library(heat-map)

# %%
import seaborn as sns                      # To import seaborn library

# %%
sns.heatmap(data_is_null)                  # Using heat_map to show null values count
# Out:
# <Axes: >

# %% [markdown]
# ### Q1. For "Ganglands", what is the Show ID and who is the Director of this show?

# %%
data.head(2)

# %%
data[data['title'].isin(['Ganglands'])]                             # To show all records of a particular item in any column
# Out:
#   show_id     type      title         director  \
# 2      s3  TV Show  Ganglands  Julien Leclercq
#
#                                                 cast country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
#
#            date_added  release_year rating  duration  \
# 2  September 24, 2021          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 2  To protect his family from a powerful drug lor...

# %%
data[data['title'].isin(['Ganglands'])] [['show_id','title','director' ]]    #To show records of a particular item for given column
# Out:
#   show_id      title         director
# 2      s3  Ganglands  Julien Leclercq

# %%
data[data['title'].str.contains('Ganglands')]                     # To show all records of a particular string in any column
# Out:
#   show_id     type      title         director  \
# 2      s3  TV Show  Ganglands  Julien Leclercq
#
#                                                 cast country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
#
#            date_added  release_year rating  duration  \
# 2  September 24, 2021          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 2  To protect his family from a powerful drug lor...

# %% [markdown]
# #### Q2. In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %% [markdown]
# #### dtypes

# %%
data.dtypes

# %% [markdown]
# #### to_datetime

# %%
data['Date_New'] = pd.to_datetime(data['date_added'])

# %%
data.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description
# 0  As her father nears the end of his life, filmm...

# %%
Highest_count_of_both = data['release_year'].value_counts().head(10)
Highest_count_of_both
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# Name: release_year, dtype: int64

# %%
movie_count = data[data['type'] == 'Movie']['release_year'].value_counts().head(1)
movie_count
# Out:
# 2017    767
# Name: release_year, dtype: int64

# %%
tvshow_count = data[data['type'] == 'TV Show']['release_year'].value_counts().head(1)
tvshow_count
# Out:
# 2020    436
# Name: release_year, dtype: int64

# %% [markdown]
# #### Bar Graph

# %%
Highest_count_of_both.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #### Q3. How many Movies and TV Shows are in the dataset? Show with Bar Graph

# %%
data['type'].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(data=data,x='type')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# #### Q4. Show all the Movies that were release in the year 2000?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
movies_2000= data[(data['type'] == 'Movie') & (data['release_year'] == 2000)]
movies_2000
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %% [markdown]
# #### Q5. Show only the Titles of all TV Shows that were released in India only

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
tvshow_india= data[(data['type']== 'TV Show') & (data['country']=='India')]['title']

tvshow_india
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [markdown]
# #### Q6.  Show Top ten directors, who gave the highest number of TV shows and Movies to Netflix?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
top_ten_directors= data['director'].value_counts().head(10)

top_ten_directors
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# #### Q7. Show all the records, where type is Movie and listed_in is Comedies or the country is United kingdom

# %%
data[(data['type']== 'Movie') & ((data['listed_in']== 'Comedies') | (data['country']== 'United Kingdom'))]
# Out:
#      show_id   type                          title  \
# 27       s28  Movie                      Grown Ups
# 152     s153  Movie  Janoskians: Untold and Untrue
# 182     s183  Movie    Welcome Home Roscoe Jenkins
# 233     s234  Movie                    Count Me In
# 292     s293  Movie                        Quartet
# ...      ...    ...                            ...
# 8732   s8733  Movie                  White Chamber
# 8733   s8734  Movie                   White Island
# 8737   s8738  Movie     Why Are We Getting So Fat?
# 8744   s8745  Movie                       Williams
# 8786   s8787  Movie                   You Can Tutu
#
#                                     director  \
# 27                              Dennis Dugan
# 152                             Brett Weiner
# 182                           Malcolm D. Lee
# 233                                  Mark Lo
# 292                           Dustin Hoffman
# ...                                      ...
# ...

# %% [markdown]
# #### Q8. In how many movies Tom Cruise was cast?

# %%
 data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
#data[data['cast'].str.contains('Tom Cruise')]                  # these function doesn't work in NaN

# %% [markdown]
# ### Create new data frame

# %%
data_new= data.dropna()                             # Created a new DataFrame and drop the NaN and then perform str.contain

# %%
data_new.head(1)
# Out:
#   show_id   type    title      director  \
# 7      s8  Movie  Sankofa  Haile Gerima
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
#
#    release_year rating duration  \
# 7          1993  TV-MA  125 min
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
#
#                                          description
# 7  On a photo shoot in Ghana, an American model s...

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description
# 341   Through chance, history and divine interventio...
# 1254  Motivated by money, a selfish workaholic seeki...

# %% [markdown]
# #### Q9.1 What are the different Ratings defined by Netflix?

# %%
data_new['rating'].nunique()
# Out:
# 14

# %%
data_new['rating'].unique()
# Out:
# array(['TV-MA', 'TV-14', 'PG-13', 'PG', 'R', 'TV-PG', 'G', 'TV-Y7',
#        'TV-G', 'TV-Y', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# #### Q9.2 How many movies got TV-14 rating in Canada?

# %%
data_new.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description
# ...

# %%
data[(data['type']== 'Movie') & (data['rating']== 'TV-14') & (data['country']== 'Canada')].shape
# Out:
# (13, 12)

# %% [markdown]
# #### Q9.3 How many TV Shows got R rating before year 2020?

# %%
data[(data['type']== 'TV Show') & (data['rating']== 'R') & (data['release_year'] < 2020)]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
# 7593   s7594  TV Show                                Nobel                NaN
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
#
#              date_added  release_year rating  duration  \
# 3893     April 25, 2019          2015      R  1 Season
# 7593  December 10, 2016          2016      R  1 Season
#
#                                             listed_in  \
# 3893                                         TV Shows
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description
# 3893  Trapped at a stagecoach stop as a storm rages ...
# 7593  A series of incidents in Afghanistan set compl...

# %% [markdown]
# #### Q10. What is the maximum duration of a Movie on Netflix

# %%
#data.duration.unique()

# %%
data[['Minutes', 'Unit']]=data['duration'].str.split(' ', expand=True)

# %%
data.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description Minutes Unit
# 0  As her father nears the end of his life, filmm...      90  min

# %%
data['Minutes']
# Out:
# 0        90
# 1         2
# 2         1
# 3         1
# 4         2
#        ...
# 8802    158
# 8803      2
# 8804     88
# 8805     88
# 8806    111
# Name: Minutes, Length: 8807, dtype: object

# %%
data['Minutes'] = pd.to_numeric(data['Minutes'])

# %%
data['Minutes'].max()
# Out:
# 312.0

# %%
data[(data['Minutes'] == data['Minutes'].max())]
# Out:
#      show_id   type                       title director  \
# 4253   s4254  Movie  Black Mirror: Bandersnatch      NaN
#
#                                                    cast        country  \
# 4253  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
#
#              date_added  release_year rating duration  \
# 4253  December 28, 2018          2018  TV-MA  312 min
#
#                                            listed_in  \
# 4253  Dramas, International Movies, Sci-Fi & Fantasy
#
#                                             description  Minutes Unit
# 4253  In 1984, a young programmer begins to question...    312.0  min

# %% [markdown]
# #### Q11. Which individual country has the highest number of TV Shows ?

# %%
data.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description  Minutes Unit
# 0  As her father nears the end of his life, filmm...     90.0  min

# %%
data_tvshow = data[data['type']== 'TV Show']

# %%
data_tvshow['country'].value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %% [markdown]
# #### Q12 Sort the data by Year

# %%
data.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
pd.to_datetime(data['date_added'])

# %%
data_year = data

# %%
data_year.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description
# 0  As her father nears the end of his life, filmm...

# %%
data_year['format_date']= pd.to_datetime(data_year['date_added']).dt.strftime('%Y-%m-%d')

# %%
data_year.sort_values(by= 'release_year').head()
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
#
#                          director                       cast        country  \
# 4250                          NaN                        NaN            NaN
# 7790                  Frank Capra                        NaN  United States
# 8205                    John Ford  Henry Fonda, Jane Darwell  United States
# 8660                    John Ford                        NaN  United States
# 8739  Frank Capra, Anatole Litvak                        NaN  United States
#
#              date_added  release_year rating  duration  \
# ...

# %% [markdown]
# #### Q13 Find all the instances where type is Movie and listed_in Dramas

# %%
data.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description format_date
# 0  As her father nears the end of his life, filmm...  2021-09-25

# %%
#data[(data['listed_in'].str.contains('Dramas')) & (data['type']== 'Movie')]

data[(data['listed_in'].str.contains('Dramas')) & (data['type']== 'Movie')]
# Out:
#      show_id   type                           title  \
# 7         s8  Movie                         Sankofa
# 9        s10  Movie                    The Starling
# 12       s13  Movie                    Je Suis Karl
# 30       s31  Movie                 Ankahi Kahaniya
# 35       s36  Movie  The Father Who Moves Mountains
# ...      ...    ...                             ...
# 8798   s8799  Movie                        Zed Plus
# 8799   s8800  Movie                           Zenda
# 8801   s8802  Movie                         Zinzana
# 8802   s8803  Movie                          Zodiac
# 8806   s8807  Movie                          Zubaan
#
#                                                director  \
# 7                                          Haile Gerima
# 9                                        Theodore Melfi
# 12                                  Christian Schwochow
# 30    Ashwiny Iyer Tiwari, Abhishek Chaubey, Saket C...
# ...
